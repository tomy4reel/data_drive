# %%
import pandas as pd

# %%
a = pd.read_csv('students.csv')
b = pd.read_csv('sub.csv')

# %%
a.head()
# Out:
#        child_id     target                 feature_1  \
# 0  ID_00603FMFS  61.962040   teacher_emotional_total
# 1  ID_006AP9OS1  44.129148    child_observe_diligent
# 2  ID_00WATQ5BZ  44.026666              child_height
# 3  ID_01C33S7YN  48.977375   teacher_emotional_total
# 4  ID_01RAL2DTR  44.983090  pri_fees_amount_std_enum
#
#                        feature_2  \
# 0                   child_height
# 1                child_dob_month
# 2      latitude_longitude_divide
# 3                      child_age
# 4  child_observe_total_mean_enum
#
#                                           feature_3  \
# 0                                         ses_proxy
# 1                               child_observe_total
# 2                            child_observe_diligent
# 3  teacher_emotional_total_pri_fees_amount_multiply
# 4                           child_observe_attentive
#
#                           feature_4  \
# 0               child_observe_total
# 1           child_observe_attentive
# ...

# %%
b.head()
# Out:
#        child_id     target      feature_1                        feature_2  \
# 0  ID_00603FMFS  59.814503  target_encode  child_observe_totalc_mean_x1000
# 1  ID_006AP9OS1  44.137751  target_encode  child_observe_totalc_mean_x1000
# 2  ID_00WATQ5BZ  46.694614  target_encode  child_observe_totalc_mean_x1000
# 3  ID_01C33S7YN  46.885931  target_encode  child_observe_totalc_mean_x1000
# 4  ID_01RAL2DTR  44.310727  target_encode  child_observe_totalc_mean_x1000
#
#                      feature_3                            feature_4  \
# 0  teacher_emotional_total_x10  child_age_child_height_multiply_x10
# 1  teacher_emotional_total_x10  child_age_child_height_multiply_x10
# 2  teacher_emotional_total_x10  child_age_child_height_multiply_x10
# 3  teacher_emotional_total_x10  child_age_child_height_multiply_x10
# 4  teacher_emotional_total_x10  child_age_child_height_multiply_x10
#
#        feature_5        feature_6                      feature_7  \
# ...

# %%
a = a.sort_values(by='child_id').reset_index(drop=True)
b = b.sort_values(by='child_id').reset_index(drop=True)

# %%
a['target'].corr(b['target'])
# Out:
# 0.9752318927365656

# %%
a['target'] = a['target']*0.7 + b['target']*0.3

# %%
a.head()
# Out:
#        child_id     target                 feature_1  \
# 0  ID_00603FMFS  61.317779   teacher_emotional_total
# 1  ID_006AP9OS1  44.131729    child_observe_diligent
# 2  ID_00WATQ5BZ  44.827050              child_height
# 3  ID_01C33S7YN  48.349942   teacher_emotional_total
# 4  ID_01RAL2DTR  44.781381  pri_fees_amount_std_enum
#
#                        feature_2  \
# 0                   child_height
# 1                child_dob_month
# 2      latitude_longitude_divide
# 3                      child_age
# 4  child_observe_total_mean_enum
#
#                                           feature_3  \
# 0                                         ses_proxy
# 1                               child_observe_total
# 2                            child_observe_diligent
# 3  teacher_emotional_total_pri_fees_amount_multiply
# 4                           child_observe_attentive
#
#                           feature_4  \
# 0               child_observe_total
# 1           child_observe_attentive
# ...

# %%
a.to_csv('ade_caleb_ensemble.csv', index=False)
